# %% [markdown]
# ### This notebook provides an example of a backtest for the MA crossover strategy in the ma_crossover.py template

# %%
import tradekit as tk

# %%
# Specify engine name and cfg path
cfg_path = {'ma_engine': './ma_engine.json'}

# Set up a notifier for email notifications
notifiers = tk.EmailNotifier(
    smtp_host='your.host',
    smtp_port=465,
    user='first.last@name.com',
    smtp_password="SMTP_PASSWORD",
    sender='first.last@name.com',
    recipients=['jane.doe@icloud.com']
)

# Set up the supervisor 
s = tk.Supervisor(backtesting=True, name='test', engine_cfgs=cfg_path)

# %%
s.run()
